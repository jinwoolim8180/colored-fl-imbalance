# %%
from utils import moving_average
import matplotlib.pyplot as plt
import pickle

with open("../results/cub/single_R[30]LR[0.0001]B[0]G[0]F[0].pkl", "rb") as f:
    result1 = pickle.load(f)

with open("../results/cub/single_R[30]LR[0.0001]B[0]G[0]F[1.0].pkl", "rb") as f:
    result2 = pickle.load(f)

x = range(4, 124, 4)

fig, ax1 = plt.subplots(figsize=(10, 8))
ax1.set_title('CUB, group 0, 3498 / 56')

ax1.set_xlabel("Round")
ax1.set_ylabel('acc', color = 'red')

plt.grid(b=True, which='major', axis='both')
ax1.plot(x, [acc[0] for acc in result1['acc']], label = 'focal loss: 0 / group&label: 00', color='darkred')
ax1.plot(x, [acc[1] for acc in result1['acc']], label = 'focal loss: 0 / group&label: 01', color='blue')
ax1.plot(x, [acc[2] for acc in result1['acc']], label = 'focal loss: 0 / group&label: 10', color='green')
ax1.plot(x, [acc[3] for acc in result1['acc']], label = 'focal loss: 0 / group&label: 11', color='deeppink')


ax1.plot(x, [acc[0] for acc in result2['acc']], label = 'focal loss: 1 / group&label: 00', color='orange')
ax1.plot(x, [acc[1] for acc in result2['acc']], label = 'focal loss: 1 / group&label: 01', color='cyan')
ax1.plot(x, [acc[2] for acc in result2['acc']], label = 'focal loss: 1 / group&label: 10', color='lightgreen')
ax1.plot(x, [acc[3] for acc in result2['acc']], label = 'focal loss: 1 / group&label: 11', color='lightpink')


ax1.legend(loc='upper right')
ax1.tick_params(axis ='y', labelcolor = 'red') 
plt.show()
# Out:
# /tmp/ipykernel_2236575/3071783254.py:23: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=True, which='major', axis='both')

# %%
from utils import moving_average
import matplotlib.pyplot as plt
import pickle

with open("../results/cub/single_R[30]LR[0.0001]B[0]G[1]F[0].pkl", "rb") as f:
    result1 = pickle.load(f)

with open("../results/cub/single_R[30]LR[0.0001]B[0]G[1]F[1.0].pkl", "rb") as f:
    result2 = pickle.load(f)

x = range(4, 124, 4)

fig, ax1 = plt.subplots(figsize=(10, 8))
ax1.set_title('CUB, group 1, 184 / 1057')

ax1.set_xlabel("Round")
ax1.set_ylabel('acc', color = 'red')

plt.grid(b=True, which='major', axis='both')
ax1.plot(x, [acc[0] for acc in result1['acc']], label = 'focal loss: 0 / group&label: 00', color='darkred')
ax1.plot(x, [acc[1] for acc in result1['acc']], label = 'focal loss: 0 / group&label: 01', color='blue')
ax1.plot(x, [acc[2] for acc in result1['acc']], label = 'focal loss: 0 / group&label: 10', color='green')
ax1.plot(x, [acc[3] for acc in result1['acc']], label = 'focal loss: 0 / group&label: 11', color='deeppink')


ax1.plot(x, [acc[0] for acc in result2['acc']], label = 'focal loss: 1 / group&label: 00', color='orange')
ax1.plot(x, [acc[1] for acc in result2['acc']], label = 'focal loss: 1 / group&label: 01', color='cyan')
ax1.plot(x, [acc[2] for acc in result2['acc']], label = 'focal loss: 1 / group&label: 10', color='lightgreen')
ax1.plot(x, [acc[3] for acc in result2['acc']], label = 'focal loss: 1 / group&label: 11', color='lightpink')

ax1.legend(loc='upper right')
ax1.tick_params(axis ='y', labelcolor = 'red') 
plt.show()
# Out:
# /tmp/ipykernel_2236575/2110965393.py:19: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=True, which='major', axis='both')

# %%
from utils import moving_average
import matplotlib.pyplot as plt
import pickle

with open("../results/cub/erm_R[15]LR[0.0001]B[0]F[0].pkl", "rb") as f:
    result1 = pickle.load(f)

with open("../results/cub/erm_R[15]LR[0.0001]B[0]F[1.0].pkl", "rb") as f:
    result2 = pickle.load(f)

x = range(4, 64, 4)

fig, ax1 = plt.subplots(figsize=(10, 8))
ax1.set_title('CUB, erm, 3682 / 1113')

ax1.set_xlabel("Round")
ax1.set_ylabel('acc', color = 'red')

plt.grid(b=True, which='major', axis='both')
ax1.plot(x, [acc[0] for acc in result1['acc']], label = 'focal loss: 0 / group&label: 00', color='darkred')
ax1.plot(x, [acc[1] for acc in result1['acc']], label = 'focal loss: 0 / group&label: 01', color='blue')
ax1.plot(x, [acc[2] for acc in result1['acc']], label = 'focal loss: 0 / group&label: 10', color='green')
ax1.plot(x, [acc[3] for acc in result1['acc']], label = 'focal loss: 0 / group&label: 11', color='deeppink')

ax1.plot(x, [acc[0] for acc in result2['acc']], label = 'focal loss: 1 / group&label: 00', color='orange')
ax1.plot(x, [acc[1] for acc in result2['acc']], label = 'focal loss: 1 / group&label: 01', color='cyan')
ax1.plot(x, [acc[2] for acc in result2['acc']], label = 'focal loss: 1 / group&label: 10', color='lightgreen')
ax1.plot(x, [acc[3] for acc in result2['acc']], label = 'focal loss: 1 / group&label: 11', color='lightpink')

ax1.legend(loc='upper right')
ax1.tick_params(axis ='y', labelcolor = 'red') 
plt.show()
# Out:
# /tmp/ipykernel_2236575/1289823102.py:19: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=True, which='major', axis='both')

# %%
from utils import moving_average
import matplotlib.pyplot as plt
import pickle

with open("../results/cub/R[30]F[0.01]LR[0.0001]D[seperate]E[1]Q[0.0]L[16.0]B[0]T[Smiling].pkl", "rb") as f:
    result1 = pickle.load(f)

with open("../results/cub/erm_R[15]LR[0.0001]B[0]F[1.0].pkl", "rb") as f:
    result2 = pickle.load(f)

x = range(4, 84, 4)

fig, ax1 = plt.subplots(figsize=(10, 8))
ax1.set_title('CUB, VFL, 3682 / 1113')

ax1.set_xlabel("Round")
ax1.set_ylabel('acc', color = 'red')

plt.grid(b=True, which='major', axis='both')
ax1.plot(x, ([acc[0] for acc in result1['acc']])[:20], label = 'focal loss: 0 / group&label: 00', color='darkred')
ax1.plot(x, ([acc[1] for acc in result1['acc']])[:20], label = 'focal loss: 0 / group&label: 01', color='blue')
ax1.plot(x, ([acc[2] for acc in result1['acc']])[:20], label = 'focal loss: 0 / group&label: 10', color='green')
ax1.plot(x, ([acc[3] for acc in result1['acc']])[:20], label = 'focal loss: 0 / group&label: 11', color='deeppink')

ax1.legend(loc='lower right')
ax1.tick_params(axis ='y', labelcolor = 'red') 
plt.show()
# Out:
# /tmp/ipykernel_3138135/2730811835.py:19: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=True, which='major', axis='both')

# %%
from utils import moving_average
import matplotlib.pyplot as plt
import pickle

with open("../results/cub/R[500]FA[0.0]FLA[0.0]LR[0.001]D[seperate]E[5]FR[1.0]C[10]FL[0]T[Smiling]WD[0.001]D[0.5pct].pkl", "rb") as f:
    result1 = pickle.load(f)

x = range(1, 501, 1)

fig, ax1 = plt.subplots(figsize=(10, 8))
ax1.set_title('CUB, VFL, 3682 / 1113')

ax1.set_xlabel("Round")
ax1.set_ylabel('acc', color = 'red')

plt.grid(visible=True, which='major', axis='both')
ax1.plot(x, ([acc[1][0] for acc in result1['acc']]), label = 'group&label: 00', color='darkred')
ax1.plot(x, ([acc[1][1] for acc in result1['acc']]), label = 'group&label: 01', color='blue')
ax1.plot(x, ([acc[1][2] for acc in result1['acc']]), label = 'group&label: 10', color='green')
ax1.plot(x, ([acc[1][3] for acc in result1['acc']]), label = 'group&label: 11', color='deeppink')

ax1.legend(loc='lower right')
ax1.tick_params(axis ='y', labelcolor = 'red') 
ax1.set_ylim(0.5, 1.0)
plt.show()

# %%
from utils import moving_average
import matplotlib.pyplot as plt
import pickle

with open("../results/cub/R[100]FA[0.01]FLA[0.0]LR[0.001]D[seperate]E[12]FR[0.3]C[100]FL[0.0]T[Smiling]WD[0.001].pkl", "rb") as f:
    result1 = pickle.load(f)

x = range(1, 101, 1)

fig, ax1 = plt.subplots(figsize=(10, 8))
ax1.set_title('CUB, VFL, 3682 / 1113')

ax1.set_xlabel("Round")
ax1.set_ylabel('acc', color = 'red')

plt.grid(visible=True, which='major', axis='both')
ax1.plot(x, ([acc[1][0] for acc in result1['acc']])[:100], label = 'group&label: 00', color='darkred')
ax1.plot(x, ([acc[1][1] for acc in result1['acc']])[:100], label = 'group&label: 01', color='blue')
ax1.plot(x, ([acc[1][2] for acc in result1['acc']])[:100], label = 'group&label: 10', color='green')
ax1.plot(x, ([acc[1][3] for acc in result1['acc']])[:100], label = 'group&label: 11', color='deeppink')

ax1.legend(loc='lower right')
ax1.tick_params(axis ='y', labelcolor = 'red') 
ax1.set_ylim(0.5, 1.0)
plt.show()

# %%
max_min = 0
for i, accs in enumerate([acc[1] for acc in result1['acc']]):
    if min(accs) > max_min:
        max_min = min(accs)
        max_index = i

# %%
[acc[1] for acc in result1['acc']][max_index]
# Out:
# [0.95, 0.93, 0.93, 0.93]

# %%
result1['acc'][max]
# Out:
# [0.918536416983086, [0.94, 0.89, 0.91, 0.9]]
